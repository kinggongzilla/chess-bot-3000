# %%
import pandas as pd
from pathlib import Path
import random

# Set display options for better viewing
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.width', None)

# Path to processed data
DATA_DIR = Path("lichess_data/data_processed")

# Find all processed parquet files
parquet_files = list(DATA_DIR.rglob("*.parquet"))
print(f"Found {len(parquet_files)} processed files\n")

# Pick a random file to inspect
if parquet_files:
    sample_file = random.choice(parquet_files)
    print(f"Inspecting: {sample_file.relative_to(DATA_DIR.parent)}\n")
    
    # Load the file
    df = pd.read_parquet(sample_file)
    
    print(f"Dataset shape: {df.shape[0]:,} rows × {df.shape[1]} columns\n")
    
    # Show column names and types
    print("Columns:")
    print(df.dtypes)
    print("\n" + "="*80 + "\n")
    
    # Show first few rows
    print("First 3 rows:")
    print(df.head(3))
    print("\n" + "="*80 + "\n")
    
    # Compare PGN vs UCI for a few examples
    print("PGN vs UCI Comparison (5 random games):")
    print("-" * 80)
    
    sample_indices = random.sample(range(len(df)), min(5, len(df)))
    
    for idx in sample_indices:
        row = df.iloc[idx]
        print(f"\nGame {idx + 1}:")
        print(f"PGN: {row['movetext'][:150]}{'...' if len(row['movetext']) > 150 else ''}")
        print(f"UCI: {row['movetext_preprocessed'][:150]}{'...' if len(row['movetext_preprocessed']) > 150 else ''}")
        
    print("\n" + "="*80 + "\n")
    
    # Statistics
    print("Statistics:")
    print(f"  Average PGN length: {df['movetext'].str.len().mean():.1f} characters")
    print(f"  Average UCI length: {df['movetext_preprocessed'].str.len().mean():.1f} characters")
    print(f"  Empty UCI conversions: {(df['movetext_preprocessed'] == '').sum()} ({(df['movetext_preprocessed'] == '').sum() / len(df) * 100:.2f}%)")
    
    # Count moves
    df['n_moves'] = df['movetext_preprocessed'].str.split().str.len()
    print(f"  Average number of moves: {df['n_moves'].mean():.1f}")
    print(f"  Min moves: {df['n_moves'].min()}")
    print(f"  Max moves: {df['n_moves'].max()}")
    
    print("\n" + "="*80 + "\n")
    
    # Show a complete game example
    print("Complete Game Example:")
    print("-" * 80)
    example = df.iloc[0]
    print(f"Original PGN:\n{example['movetext']}\n")
    print(f"Converted UCI:\n{example['movetext_preprocessed']}\n")
    
else:
    print("No processed files found!")
# Out:
# Found 2 processed files
#
# Inspecting: data_processed/year=2023/month=01/train-00000-of-00433.parquet
#
# Dataset shape: 238,288 rows × 19 columns
#
# Columns:
# Event                     object
# Site                      object
# White                     object
# Black                     object
# Result                    object
# WhiteTitle                object
# BlackTitle                object
# WhiteElo                   int16
# BlackElo                   int16
# WhiteRatingDiff          float64
# BlackRatingDiff          float64
# UTCDate                   object
# UTCTime                   object
# ECO                       object
# Opening                   object
# Termination               object
# TimeControl               object
# movetext                  object
# movetext_preprocessed     object
# dtype: object
#
# ================================================================================
#
# First 3 rows:
#                Event                          Site       White       Black  \
# 0  Rated Bullet game  https://lichess.org/JRgTjrR2   Murzillka   LokiAThor
# 1  Rated Bullet game  https://lichess.org/d8dLSgmz  ondra12345  ducknorris
# 2  Rated Bullet game  https://lichess.org/mJ8Oemdm  dawoodmans     Lithren
#
#   Result WhiteTitle BlackTitle  WhiteElo  BlackElo  WhiteRatingDiff  \
# 0    1-0       None       None      2186      2218              6.0
# 1    1-0       None       None      1658      1670              6.0
# 2    0-1       None       None      1454      1439             -6.0
#
#    BlackRatingDiff     UTCDate   UTCTime  ECO  \
# 0             -6.0  2023-01-01  00:00:11  A00
# 1            -22.0  2023-01-01  00:00:11  B32
# 2              6.0  2023-01-01  00:00:11  C20
#
#                                        Opening   Termination TimeControl  \
# 0                               Mieses Opening  Time forfeit        60+0
# 1  Sicilian Defense: Franco-Sicilian Variation  Time forfeit        60+0
# 2        King's Pawn Game: Leonardis Variation        Normal        60+0
#
#                                                                                               movetext  \
# 0  1. d3 { [%clk 0:01:00] } 1... d5 { [%clk 0:01:00] } 2. e3 { [%clk 0:01:00] } 2... c5 { [%clk 0:0...
# 1  1. e4 { [%clk 0:01:00] } 1... c5 { [%clk 0:01:00] } 2. Nf3 { [%clk 0:00:59] } 2... Nc6 { [%clk 0...
# 2  1. e4 { [%clk 0:01:00] } 1... e5 { [%clk 0:01:00] } 2. d3 { [%clk 0:00:59] } 2... Nc6 { [%clk 0:...
#
#                                                                                  movetext_preprocessed
# 0  <BOG> d2d3 d7d5 e2e3 c7c5 f2f3 b8c6 g2g3 g7g6 f1g2 f8g7 g1e2 g8f6 e1g1 e7e5 h2h3 e8g8 g1h2 c8e6 ...
# 1                                                       <BOG> e2e4 c7c5 g1f3 b8c6 d2d4 e7e6 d4d5 <EOG>
# 2  <BOG> e2e4 e7e5 d2d3 b8c6 b1c3 f8c5 c1g5 f7f6 g5e3 c5b6 e3b6 a7b6 g1f3 d7d6 f1e2 c8g4 d1d2 h7h5 ...
#
# ================================================================================
#
# PGN vs UCI Comparison (5 random games):
# --------------------------------------------------------------------------------
#
# Game 159918:
# PGN: 1. d4 { [%clk 0:03:00] } 1... d5 { [%clk 0:03:00] } 2. e3 { [%clk 0:02:52] } 2... g6 { [%clk 0:03:01] } 3. Bd3 { [%clk 0:02:34] } 3... Bg7 { [%clk 0:0...
# UCI: <BOG> d2d4 d7d5 e2e3 g7g6 f1d3 f8g7 g1f3 c8g4 b1d2 g4f3 d2f3 e7e6 e1g1 g8e7 c2c4 c7c6 b2b3 b8d7 c1b2 e7f5 d1e2 e8g8 e3e4 f5d6 e4e5 d6f5 d3f5 e6f5 f3g5...
#
# Game 14927:
# PGN: 1. e4 { [%clk 0:05:00] } 1... e5 { [%clk 0:05:00] } 2. f4 { [%clk 0:04:59] } 2... exf4 { [%clk 0:04:59] } 3. Nf3 { [%clk 0:04:58] } 3... f6 { [%clk 0:...
# UCI: <BOG> e2e4 e7e5 f2f4 e5f4 g1f3 f7f6 f1c4 h7h5 d2d4 g7g5 e1g1 d7d6 d1e2 a7a6 e4e5 d6d5 e5f6 e8f7 f3e5 f7f6 c4b3 f8d6 b1c3 c8f5 c3d5 f6g7 c2c3 c7c6 d5e3...
#
# Game 71787:
# PGN: 1. d4 { [%clk 0:01:00] } 1... d5 { [%clk 0:01:00] } 2. Bg5 { [%clk 0:00:59] } 2... Nf6 { [%clk 0:01:00] } 3. Bf4 { [%clk 0:00:57] } 3... e6 { [%clk 0:...
# UCI: <BOG> d2d4 d7d5 c1g5 g8f6 g5f4 e7e6 f4c7 f8d6 c7d8 e8d8 g1f3 d8d7 f3e5 d7e8 b1c3 b7b6 c3b5 e8e7 b5d6 e7d6 e5f7 d6e7 f7h8 c8b7 d1d3 b8c6 h8g6 h7g6 d3g6...
#
# Game 166255:
# PGN: 1. e4 { [%clk 0:03:00] } 1... c5 { [%clk 0:03:00] } 2. Nf3 { [%clk 0:03:00] } 2... d6 { [%clk 0:03:01] } 3. d4 { [%clk 0:02:59] } 3... cxd4 { [%clk 0:...
# UCI: <BOG> e2e4 c7c5 g1f3 d7d6 d2d4 c5d4 f3d4 g8f6 b1c3 a7a6 f1e2 e7e6 e1g1 f8e7 c1g5 b7b5 a2a3 c8b7 e2f3 e8g8 g5f6 e7f6 e4e5 b7f3 d1f3 f6e5 f3a8 d6d5 d4c6...
#
# Game 192014:
# PGN: 1. d4 { [%clk 0:05:00] } 1... Nf6 { [%clk 0:05:00] } 2. c4 { [%clk 0:05:02] } 2... e6 { [%clk 0:05:02] } 3. Nc3 { [%clk 0:05:04] } 3... Bb4 { [%clk 0:...
# UCI: <BOG> d2d4 g8f6 c2c4 e7e6 b1c3 f8b4 a2a3 b4c3 b2c3 d7d5 e2e3 b8d7 f1d3 d5c4 d3c4 c7c5 g1e2 c5d4 c3d4 d7b6 c4d3 c8d7 e1g1 d7c6 e2g3 d8d5 c1b2 d5g2 <EOG...
#
# ================================================================================
#
# Statistics:
#   Average PGN length: 1895.3 characters
#   Average UCI length: 338.1 characters
#   Empty UCI conversions: 0 (0.00%)
#   Average number of moves: 67.4
#   Min moves: 2
#   Max moves: 350
#
# ================================================================================
#
# Complete Game Example:
# --------------------------------------------------------------------------------
# Original PGN:
# 1. d3 { [%clk 0:01:00] } 1... d5 { [%clk 0:01:00] } 2. e3 { [%clk 0:01:00] } 2... c5 { [%clk 0:01:00] } 3. f3 { [%clk 0:01:00] } 3... Nc6 { [%clk 0:00:59] } 4. g3 { [%clk 0:01:00] } 4... g6 { [%clk 0:00:59] } 5. Bg2 { [%clk 0:01:00] } 5... Bg7 { [%clk 0:00:59] } 6. Ne2 { [%clk 0:00:59] } 6... Nf6 { [%clk 0:00:59] } 7. O-O { [%clk 0:00:59] } 7... e5 { [%clk 0:00:59] } 8. h3 { [%clk 0:00:59] } 8... O-O { [%clk 0:00:59] } 9. Kh2 { [%clk 0:00:59] } 9... Be6 { [%clk 0:00:58] } 10. Nd2 { [%clk 0:00:58] } 10... h5 { [%clk 0:00:57] } 11. f4 { [%clk 0:00:58] } 11... exf4 { [%clk 0:00:56] } 12. exf4 { [%clk 0:00:57] } 12... Qd7 { [%clk 0:00:54] } 13. Ng1 { [%clk 0:00:57] } 13... Rae8 { [%clk 0:00:53] } 14. Ndf3 { [%clk 0:00:57] } 14... b5 { [%clk 0:00:51] } 15. Rb1 { [%clk 0:00:57] } 15... a5 { [%clk 0:00:50] } 16. c3 { [%clk 0:00:56] } 16... a4 { [%clk 0:00:49] } 17. Bd2 { [%clk 0:00:56] } 17... d4 { [%clk 0:00:48] } 18. Qc2 { [%clk 0:00:55] } 18... dxc3 { [%clk 0:00:47] } 19. bxc3 { [%clk 0:00:55] } 19... Rb8 { [%clk 0:00:44] } 20. Rfe1 { [%clk 0:00:53] } 20... Rfe8 { [%clk 0:00:43] } 21. Ne5 { [%clk 0:00:53] } 21... Nxe5 { [%clk 0:00:42] } 22. Rxe5 { [%clk 0:00:52] } 22... Nd5 { [%clk 0:00:40] } 23. Ree1 { [%clk 0:00:52] } 23... b4 { [%clk 0:00:39] } 24. c4 { [%clk 0:00:51] } 24... Nc7 { [%clk 0:00:37] } 25. Nf3 { [%clk 0:00:49] } 25... Bf5 { [%clk 0:00:36] } 26. Rxe8+ { [%clk 0:00:44] } 26... Rxe8 { [%clk 0:00:35] } 27. Ne1 { [%clk 0:00:44] } 27... Ne6 { [%clk 0:00:34] } 28. Qd1 { [%clk 0:00:42] } 28... Bxd3 { [%clk 0:00:32] } 29. Bxb4 { [%clk 0:00:40] } 29... cxb4 { [%clk 0:00:23] } 30. Nxd3 { [%clk 0:00:37] } 30... Nd4 { [%clk 0:00:22] } 31. Nf2 { [%clk 0:00:36] } 31... b3 { [%clk 0:00:20] } 32. axb3 { [%clk 0:00:35] } 32... axb3 { [%clk 0:00:20] } 33. Rxb3 { [%clk 0:00:33] } 33... Qa7 { [%clk 0:00:17] } 34. Rd3 { [%clk 0:00:32] } 34... Qa2 { [%clk 0:00:15] } 35. Rd2 { [%clk 0:00:30] } 35... Qxc4 { [%clk 0:00:14] } 36. Ne4 { [%clk 0:00:28] } 36... f5 { [%clk 0:00:09] } 37. Ng5 { [%clk 0:00:27] } 37... Bf6 { [%clk 0:00:08] } 38. Nf3 { [%clk 0:00:25] } 38... Nxf3+ { [%clk 0:00:06] } 39. Bxf3 { [%clk 0:00:25] } 39... Re3 { [%clk 0:00:05] } 40. Rd8+ { [%clk 0:00:23] } 40... Bxd8 { [%clk 0:00:04] } 41. Qxd8+ { [%clk 0:00:22] } 41... Kg7 { [%clk 0:00:03] } 42. Qd7+ { [%clk 0:00:21] } 42... Qf7 { [%clk 0:00:02] } 43. Qd4+ { [%clk 0:00:20] } 43... Qf6 { [%clk 0:00:01] } 44. Qxe3 { [%clk 0:00:20] } 44... h4 { [%clk 0:00:00] } 45. Qe5 { [%clk 0:00:19] } 45... Kh6 { [%clk 0:00:00] } 46. Qxf6 { [%clk 0:00:18] } 46... hxg3+ { [%clk 0:00:00] } 47. Kxg3 { [%clk 0:00:17] } 1-0
#
# Converted UCI:
# <BOG> d2d3 d7d5 e2e3 c7c5 f2f3 b8c6 g2g3 g7g6 f1g2 f8g7 g1e2 g8f6 e1g1 e7e5 h2h3 e8g8 g1h2 c8e6 b1d2 h7h5 f3f4 e5f4 e3f4 d8d7 e2g1 a8e8 d2f3 b7b5 a1b1 a7a5 c2c3 a5a4 c1d2 d5d4 d1c2 d4c3 b2c3 e8b8 f1e1 f8e8 f3e5 c6e5 e1e5 f6d5 e5e1 b5b4 c3c4 d5c7 g1f3 e6f5 e1e8 b8e8 f3e1 c7e6 c2d1 f5d3 d2b4 c5b4 e1d3 e6d4 d3f2 b4b3 a2b3 a4b3 b1b3 d7a7 b3d3 a7a2 d3d2 a2c4 f2e4 f7f5 e4g5 g7f6 g5f3 d4f3 g2f3 e8e3 d2d8 f6d8 d1d8 g8g7 d8d7 c4f7 d7d4 f7f6 d4e3 h5h4 e3e5 g7h6 e5f6 h4g3 h2g3 <EOG>

# %%
file_path = "lichess_data/data_processed/year=2023/month=01/train-00001-of-00433.parquet"
df = pd.read_parquet(file_path)
print(df.columns)
# Out:
# Index(['Event', 'Site', 'White', 'Black', 'Result', 'WhiteTitle', 'BlackTitle',
#        'WhiteElo', 'BlackElo', 'WhiteRatingDiff', 'BlackRatingDiff', 'UTCDate',
#        'UTCTime', 'ECO', 'Opening', 'Termination', 'TimeControl', 'movetext',
#        'movetext_preprocessed'],
#       dtype='object')

# %%
df.iloc[0]["movetext_preprocessed"]
# Out:
# '<BOG> d2d4 d7d6 c2c4 g8f6 e2e3 h7h6 g1f3 g7g6 f1e2 f8g7 b1c3 e8g8 c3d5 c7c6 d5f6 g7f6 b2b4 c6c5 b4c5 d6c5 c1b2 c5d4 b2d4 f6d4 f3d4 b8c6 d4f3 d8d1 a1d1 c8e6 e1g1 g8g7 a2a3 a7a6 d1a1 c6a5 a1c1 a5b3 c1c3 b3c5 f3d4 c5e4 d4e6 f7e6 c3c2 a8d8 f2f3 e4c5 e3e4 e6e5 h2h3 c5e6 g2g3 e6d4 c2a2 d4e2 a2e2 d8d3 e2a2 d3c3 g3g4 c3c4 g1g2 g6g5 g2g3 f8c8 h3h4 g5h4 g3h4 c4c2 a2c2 c8c2 f1h1 c2c3 h1h3 c3a3 g4g5 h6g5 h4g5 b7b5 g5f5 b5b4 f5e5 b4b3 h3g3 g7f7 f3f4 a6a5 f4f5 a5a4 e5d5 a3a1 d5c4 a1c1 c4b4 c1a1 e4e5 b3b2 e5e6 f7f6 <EOG>'

# %%
from transformers import GPT2LMHeadModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("nsarrazin/chessformer")

#add <BOG> and <EOG> tokens
tokenizer.add_special_tokens({'additional_special_tokens': ['<BOG>', '<EOG>']})

moves = df.iloc[0]["movetext_preprocessed"]
print(moves)

# Print the tokens
print("Tokens:", tokenizer.tokenize(moves))
# Out:
# <BOG> d2d4 d7d6 c2c4 g8f6 e2e3 h7h6 g1f3 g7g6 f1e2 f8g7 b1c3 e8g8 c3d5 c7c6 d5f6 g7f6 b2b4 c6c5 b4c5 d6c5 c1b2 c5d4 b2d4 f6d4 f3d4 b8c6 d4f3 d8d1 a1d1 c8e6 e1g1 g8g7 a2a3 a7a6 d1a1 c6a5 a1c1 a5b3 c1c3 b3c5 f3d4 c5e4 d4e6 f7e6 c3c2 a8d8 f2f3 e4c5 e3e4 e6e5 h2h3 c5e6 g2g3 e6d4 c2a2 d4e2 a2e2 d8d3 e2a2 d3c3 g3g4 c3c4 g1g2 g6g5 g2g3 f8c8 h3h4 g5h4 g3h4 c4c2 a2c2 c8c2 f1h1 c2c3 h1h3 c3a3 g4g5 h6g5 h4g5 b7b5 g5f5 b5b4 f5e5 b4b3 h3g3 g7f7 f3f4 a6a5 f4f5 a5a4 e5d5 a3a1 d5c4 a1c1 c4b4 c1a1 e4e5 b3b2 e5e6 f7f6 <EOG>
# Tokens: ['<BOG>', 'd2d4', 'd7d6', 'c2c4', 'g8f6', 'e2e3', 'h7h6', 'g1f3', 'g7g6', 'f1e2', 'f8g7', 'b1c3', 'e8g8', 'c3d5', 'c7c6', 'd5f6', 'g7f6', 'b2b4', 'c6c5', 'b4c5', 'd6c5', 'c1b2', 'c5d4', 'b2d4', 'f6d4', 'f3d4', 'b8c6', 'd4f3', 'd8d1', 'a1d1', 'c8e6', 'e1g1', 'g8g7', 'a2a3', 'a7a6', 'd1a1', 'c6a5', 'a1c1', 'a5b3', 'c1c3', 'b3c5', 'f3d4', 'c5e4', 'd4e6', 'f7e6', 'c3c2', 'a8d8', 'f2f3', 'e4c5', 'e3e4', 'e6e5', 'h2h3', 'c5e6', 'g2g3', 'e6d4', 'c2a2', 'd4e2', 'a2e2', 'd8d3', 'e2a2', 'd3c3', 'g3g4', 'c3c4', 'g1g2', 'g6g5', 'g2g3', 'f8c8', 'h3h4', 'g5h4', 'g3h4', 'c4c2', 'a2c2', 'c8c2', 'f1h1', 'c2c3', 'h1h3', 'c3a3', 'g4g5', 'h6g5', 'h4g5', 'b7b5', 'g5f5', 'b5b4', 'f5e5', 'b4b3', 'h3g3', 'g7f7', 'f3f4', 'a6a5', 'f4f5', 'a5a4', 'e5d5', 'a3a1', 'd5c4', 'a1c1', 'c4b4', 'c1a1', 'e4e5', 'b3b2', 'e5e6', 'f7f6', '<EOG>']

# %%
# tokenizer = AutoTokenizer.from_pretrained("../tokenizer/uci_tokenizer_with_special_tokens")
print(f"BOS token: {tokenizer.bos_token} (id: {tokenizer.bos_token_id})")
print(f"EOS token: {tokenizer.eos_token} (id: {tokenizer.eos_token_id})")
# Out:
# BOS token: None (id: None)
# EOS token: None (id: None)
