# %%
import pandas as pd

# %% [markdown]
# ### original data

# %%
file_path = "lichess_data/data/year=2023/month=01/train-00001-of-00433.parquet"
df = pd.read_parquet(file_path)
print(df.columns)
# Out:
# Index(['Event', 'Site', 'White', 'Black', 'Result', 'WhiteTitle', 'BlackTitle',
#        'WhiteElo', 'BlackElo', 'WhiteRatingDiff', 'BlackRatingDiff', 'UTCDate',
#        'UTCTime', 'ECO', 'Opening', 'Termination', 'TimeControl', 'movetext'],
#       dtype='object')

# %%
# print first 20 result rows
print(df['Result'].head(20))
# Out:
# 0         0-1
# 1         1-0
# 2     1/2-1/2
# 3         1-0
# 4         1-0
# 5         0-1
# 6         0-1
# 7         0-1
# 8         0-1
# 9         0-1
# 10        0-1
# 11        1-0
# 12        1-0
# 13        1-0
# 14        1-0
# 15        1-0
# 16        0-1
# 17        1-0
# 18        0-1
# 19        1-0
# Name: Result, dtype: object

# %%
# df.head()

# %% [markdown]
# ### preprocessed data

# %%
import pandas as pd
from pathlib import Path
import random

# Set display options for better viewing
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.width', None)

# Path to processed data
DATA_DIR = Path("lichess_data/data_processed")

# Find all processed parquet files
parquet_files = list(DATA_DIR.rglob("*.parquet"))
print(f"Found {len(parquet_files)} processed files\n")

# Pick a random file to inspect
if parquet_files:
    sample_file = random.choice(parquet_files)
    print(f"Inspecting: {sample_file.relative_to(DATA_DIR.parent)}\n")
    
    # Load the file
    df = pd.read_parquet(sample_file)
    
    print(f"Dataset shape: {df.shape[0]:,} rows × {df.shape[1]} columns\n")
    
    # Show column names and types
    print("Columns:")
    print(df.dtypes)
    print("\n" + "="*80 + "\n")
    
    # Show first few rows
    print("First 3 rows:")
    print(df.head(3))
    print("\n" + "="*80 + "\n")
    
    # Compare PGN vs UCI for a few examples
    print("PGN vs UCI Comparison (5 random games):")
    print("-" * 80)
    
    sample_indices = random.sample(range(len(df)), min(5, len(df)))
    
    for idx in sample_indices:
        row = df.iloc[idx]
        print(f"\nGame {idx + 1}:")
        print(f"PGN: {row['movetext_uci'][:150]}{'...' if len(row['movetext_uci']) > 150 else ''}")
        print(f"UCI: {row['movetext_uci'][:150]}{'...' if len(row['movetext_uci']) > 150 else ''}")
        
    print("\n" + "="*80 + "\n")
    
    # Statistics
    print("Statistics:")
    print(f"  Average PGN length: {df['movetext_uci'].str.len().mean():.1f} characters")
    print(f"  Average UCI length: {df['movetext_uci'].str.len().mean():.1f} characters")
    print(f"  Empty UCI conversions: {(df['movetext_uci'] == '').sum()} ({(df['movetext_uci'] == '').sum() / len(df) * 100:.2f}%)")
    
    # Count moves
    df['n_moves'] = df['movetext_uci'].str.split().str.len()
    print(f"  Average number of moves: {df['n_moves'].mean():.1f}")
    print(f"  Min moves: {df['n_moves'].min()}")
    print(f"  Max moves: {df['n_moves'].max()}")
    
    print("\n" + "="*80 + "\n")
    
    # Show a complete game example
    print("Complete Game Example:")
    print("-" * 80)
    example = df.iloc[0]
    print(f"Converted UCI:\n{example['movetext_uci']}\n")
    
else:
    print("No processed files found!")
# Out:
# Found 2 processed files
#
# Inspecting: data_processed/year=2023/month=01/train-00000-of-00433.parquet
#
# Dataset shape: 238,288 rows × 1 columns
#
# Columns:
# movetext_uci    object
# dtype: object
#
# ================================================================================
#
# First 3 rows:
#                                                                                           movetext_uci
# 0  <BOG> <WHITE:2200> <BLACK:2200> <WHITE_WIN> d2d3 d7d5 e2e3 c7c5 f2f3 b8c6 g2g3 g7g6 f1g2 f8g7 g1...
# 1                 <BOG> <WHITE:1700> <BLACK:1700> <WHITE_WIN> e2e4 c7c5 g1f3 b8c6 d2d4 e7e6 d4d5 <EOG>
# 2  <BOG> <WHITE:1500> <BLACK:1400> <BLACK_WIN> e2e4 e7e5 d2d3 b8c6 b1c3 f8c5 c1g5 f7f6 g5e3 c5b6 e3...
#
# ================================================================================
#
# PGN vs UCI Comparison (5 random games):
# --------------------------------------------------------------------------------
#
# Game 120639:
# PGN: <BOG> <WHITE:1400> <BLACK:1400> <WHITE_WIN> e2e4 c7c5 g1f3 b8c6 b1c3 g7g6 d2d4 c5d4 f3d4 f8g7 c1f4 c6d4 c3d5 e7e6 d5c7 e8e7 c7a8 b7b6 a8c7 c8b7 c2c3 d...
# UCI: <BOG> <WHITE:1400> <BLACK:1400> <WHITE_WIN> e2e4 c7c5 g1f3 b8c6 b1c3 g7g6 d2d4 c5d4 f3d4 f8g7 c1f4 c6d4 c3d5 e7e6 d5c7 e8e7 c7a8 b7b6 a8c7 c8b7 c2c3 d...
#
# Game 174503:
# PGN: <BOG> <WHITE:1400> <BLACK:1500> <WHITE_WIN> d2d4 d7d5 c2c4 e7e6 b1c3 g8f6 g1f3 f8b4 h2h4 e8g8 h4h5 h7h6 f3e5 f6e4 c1d2 e4d2 d1d2 f7f6 e5g6 f8f7 e1c1 f...
# UCI: <BOG> <WHITE:1400> <BLACK:1500> <WHITE_WIN> d2d4 d7d5 c2c4 e7e6 b1c3 g8f6 g1f3 f8b4 h2h4 e8g8 h4h5 h7h6 f3e5 f6e4 c1d2 e4d2 d1d2 f7f6 e5g6 f8f7 e1c1 f...
#
# Game 229735:
# PGN: <BOG> <WHITE:1700> <BLACK:1600> <BLACK_WIN> g1f3 d7d5 g2g3 e7e6 f1g2 g8f6 e1g1 f8e7 d2d3 e8g8 f1e1 b8c6 b1c3 b7b6 e2e4 c8b7 e4e5 f6d7 d3d4 f7f6 e5f6 e...
# UCI: <BOG> <WHITE:1700> <BLACK:1600> <BLACK_WIN> g1f3 d7d5 g2g3 e7e6 f1g2 g8f6 e1g1 f8e7 d2d3 e8g8 f1e1 b8c6 b1c3 b7b6 e2e4 c8b7 e4e5 f6d7 d3d4 f7f6 e5f6 e...
#
# Game 218682:
# PGN: <BOG> <WHITE:2000> <BLACK:2200> <BLACK_WIN> d2d4 g8f6 g1f3 g7g6 c1g5 f8g7 e2e3 e8g8 f1e2 c7c5 d4d5 d7d6 c2c3 c8g4 e1g1 a7a6 h2h3 g4f3 e2f3 b7b5 b1d2 b...
# UCI: <BOG> <WHITE:2000> <BLACK:2200> <BLACK_WIN> d2d4 g8f6 g1f3 g7g6 c1g5 f8g7 e2e3 e8g8 f1e2 c7c5 d4d5 d7d6 c2c3 c8g4 e1g1 a7a6 h2h3 g4f3 e2f3 b7b5 b1d2 b...
#
# Game 16492:
# PGN: <BOG> <WHITE:1800> <BLACK:1900> <BLACK_WIN> d2d3 d7d5 e2e4 d5e4 b1c3 e4d3 f1d3 e7e5 g1f3 b8c6 d1e2 c8g4 h2h3 g4f3 e2f3 g8f6 c1g5 f8e7 e1c1 c6d4 f3b7 e...
# UCI: <BOG> <WHITE:1800> <BLACK:1900> <BLACK_WIN> d2d3 d7d5 e2e4 d5e4 b1c3 e4d3 f1d3 e7e5 g1f3 b8c6 d1e2 c8g4 h2h3 g4f3 e2f3 g8f6 c1g5 f8e7 e1c1 c6d4 f3b7 e...
#
# ================================================================================
#
# Statistics:
#   Average PGN length: 375.8 characters
#   Average UCI length: 375.8 characters
#   Empty UCI conversions: 0 (0.00%)
#   Average number of moves: 70.4
#   Min moves: 5
#   Max moves: 353
#
# ================================================================================
#
# Complete Game Example:
# --------------------------------------------------------------------------------
# Converted UCI:
# <BOG> <WHITE:2200> <BLACK:2200> <WHITE_WIN> d2d3 d7d5 e2e3 c7c5 f2f3 b8c6 g2g3 g7g6 f1g2 f8g7 g1e2 g8f6 e1g1 e7e5 h2h3 e8g8 g1h2 c8e6 b1d2 h7h5 f3f4 e5f4 e3f4 d8d7 e2g1 a8e8 d2f3 b7b5 a1b1 a7a5 c2c3 a5a4 c1d2 d5d4 d1c2 d4c3 b2c3 e8b8 f1e1 f8e8 f3e5 c6e5 e1e5 f6d5 e5e1 b5b4 c3c4 d5c7 g1f3 e6f5 e1e8 b8e8 f3e1 c7e6 c2d1 f5d3 d2b4 c5b4 e1d3 e6d4 d3f2 b4b3 a2b3 a4b3 b1b3 d7a7 b3d3 a7a2 d3d2 a2c4 f2e4 f7f5 e4g5 g7f6 g5f3 d4f3 g2f3 e8e3 d2d8 f6d8 d1d8 g8g7 d8d7 c4f7 d7d4 f7f6 d4e3 h5h4 e3e5 g7h6 e5f6 h4g3 h2g3 <EOG>

# %%
file_path = "lichess_data/data_processed/year=2023/month=01/train-00000-of-00433.parquet"
df = pd.read_parquet(file_path)
print(df.columns)
# Out:
# Index(['movetext_uci'], dtype='object')

# %%
df.iloc[2]["movetext_uci"]
# Out:
# '<BOG> <WHITE:1500> <BLACK:1400> <BLACK_WIN> e2e4 e7e5 d2d3 b8c6 b1c3 f8c5 c1g5 f7f6 g5e3 c5b6 e3b6 a7b6 g1f3 d7d6 f1e2 c8g4 d1d2 h7h5 h2h3 g4e6 e1c1 d8b8 c1b1 b8a7 g2g4 c6d4 g4h5 d4e2 d2e2 h8h5 f3g1 h5h8 e2f3 b6b5 g1e2 b5b4 b2b3 b4c3 e2c3 b7b5 c3b5 a7a2 b1c1 a2a1 c1d2 a1a5 b5c3 g8e7 h1g1 e7c6 g1g7 c6d4 d1g1 d4f3 d2e3 f3g1 g7g1 a5c3 e3e2 e8d7 e2d1 h8g8 d1e2 g8g1 f2f3 c3e1 <EOG>'

# %%
from transformers import GPT2LMHeadModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("nsarrazin/chessformer")

#add <BOG> and <EOG> tokens
tokenizer.add_special_tokens({'additional_special_tokens': ['<BOG>', '<EOG>']})

moves = df.iloc[0]["movetext_uci"]
print(moves)

# Print the tokens
print("Tokens:", tokenizer.tokenize(moves))
# Out:
# <BOG> <WHITE:1700> <BLACK:1700> <BLACK_WIN> d2d4 d7d6 c2c4 g8f6 e2e3 h7h6 g1f3 g7g6 f1e2 f8g7 b1c3 e8g8 c3d5 c7c6 d5f6 g7f6 b2b4 c6c5 b4c5 d6c5 c1b2 c5d4 b2d4 f6d4 f3d4 b8c6 d4f3 d8d1 a1d1 c8e6 e1g1 g8g7 a2a3 a7a6 d1a1 c6a5 a1c1 a5b3 c1c3 b3c5 f3d4 c5e4 d4e6 f7e6 c3c2 a8d8 f2f3 e4c5 e3e4 e6e5 h2h3 c5e6 g2g3 e6d4 c2a2 d4e2 a2e2 d8d3 e2a2 d3c3 g3g4 c3c4 g1g2 g6g5 g2g3 f8c8 h3h4 g5h4 g3h4 c4c2 a2c2 c8c2 f1h1 c2c3 h1h3 c3a3 g4g5 h6g5 h4g5 b7b5 g5f5 b5b4 f5e5 b4b3 h3g3 g7f7 f3f4 a6a5 f4f5 a5a4 e5d5 a3a1 d5c4 a1c1 c4b4 c1a1 e4e5 b3b2 e5e6 f7f6 <EOG>
# Tokens: ['<BOG>', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '[UNK]', '<BLACK_WIN>', 'd2d4', 'd7d6', 'c2c4', 'g8f6', 'e2e3', 'h7h6', 'g1f3', 'g7g6', 'f1e2', 'f8g7', 'b1c3', 'e8g8', 'c3d5', 'c7c6', 'd5f6', 'g7f6', 'b2b4', 'c6c5', 'b4c5', 'd6c5', 'c1b2', 'c5d4', 'b2d4', 'f6d4', 'f3d4', 'b8c6', 'd4f3', 'd8d1', 'a1d1', 'c8e6', 'e1g1', 'g8g7', 'a2a3', 'a7a6', 'd1a1', 'c6a5', 'a1c1', 'a5b3', 'c1c3', 'b3c5', 'f3d4', 'c5e4', 'd4e6', 'f7e6', 'c3c2', 'a8d8', 'f2f3', 'e4c5', 'e3e4', 'e6e5', 'h2h3', 'c5e6', 'g2g3', 'e6d4', 'c2a2', 'd4e2', 'a2e2', 'd8d3', 'e2a2', 'd3c3', 'g3g4', 'c3c4', 'g1g2', 'g6g5', 'g2g3', 'f8c8', 'h3h4', 'g5h4', 'g3h4', 'c4c2', 'a2c2', 'c8c2', 'f1h1', 'c2c3', 'h1h3', 'c3a3', 'g4g5', 'h6g5', 'h4g5', 'b7b5', 'g5f5', 'b5b4', 'f5e5', 'b4b3', 'h3g3', 'g7f7', 'f3f4', 'a6a5', 'f4f5', 'a5a4', 'e5d5', 'a3a1', 'd5c4', 'a1c1', 'c4b4', 'c1a1', 'e4e5', 'b3b2', 'e5e6', 'f7f6', '<EOG>']

# %%
# tokenizer = AutoTokenizer.from_pretrained("../tokenizer/uci_tokenizer_with_special_tokens")
print(f"BOS token: {tokenizer.bos_token} (id: {tokenizer.bos_token_id})")
print(f"EOS token: {tokenizer.eos_token} (id: {tokenizer.eos_token_id})")
# Out:
# BOS token: None (id: None)
# EOS token: None (id: None)
